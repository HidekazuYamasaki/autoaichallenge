# %%
# !pip install nbconvert
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# !cp drive/MyDrive/[directory name]/[file name.ipynb] ./
#
# ※カレントディレクトリは、driveディレクトリの1つ上

# %%
#!ls /content/drive/MyDrive/TensorFlow\ Tutorial
# !cp drive/MyDrive/TensorFlow\ Tutorial/beginner01.ipynb ./
# !ls
# Out:
# beginner01.ipynb	drive			      sample_data
# classification01.html	overfit_and_underfit01.html
# classification01.ipynb	overfit_and_underfit01.ipynb

# %% [markdown]
# !jupyter nbconvert --to html "file name.ipynb"

# %%
# !jupyter nbconvert --to html "beginner01.ipynb"
# Out:
# [NbConvertApp] Converting notebook beginner01.ipynb to html
# [NbConvertApp] Writing 339990 bytes to beginner01.html

# %% [markdown]
# GoogleColaboratoryの左側にあるファイルタブを開き（閉じている場合はファイルボタンから開く）、変換後のhtmlファイルをダウンロードしてください。
#
# pdfに変換する場合は、ブラウザでhtmlファイルを開き、「印刷」→「PDFで保存」でレイアウトを確認して保存してください。
